# %% [markdown]
# # Student Marks and Percentage calculator

# %%
Name = "Mohammad Wasayullah"
Eng = 78
Urd = 77
Isl = 50 
Math = 93 
Ttq = 47
Phy = 67
Cs = 69 
Total_Marks = 560
Obatined_Marks = Eng+Isl+Urd+Math+Ttq+Phy+Cs
Percentage = (Obatined_Marks/Total_Marks)*100

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 Total_Marks = 560
# ----> 2 Obatined_Marks = Eng+Isl+Urd+Math+Ttq+Phy+Cs
#       3 Percentage = (Obatined_Marks/Total_Marks)*100
#
# NameError: name 'Eng' is not defined
