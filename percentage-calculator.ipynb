# %% [markdown]
# # Student Marks and Percentage calculator

# %%
Name = "Mohammad Wasayullah"
Total_Marks = 560
Eng = 78
Urd = 77
Isl = 50 
Math = 93 
Ttq = 47
Phy = 67
Cs = 69 
Obatined_Marks = Eng+Isl+Urd+Math+Ttq+Phy+Cs
Percentage = (Obatined_Mark
s//Total_Marks)*100

# %%
print(Percentage)
# Out:
# 85.89285714285714
